# %%
print('hello world, my name is bart')
# Out:
# hello world, my name is bart

# %%
print('this is sub assigment 1')
print('this is sub assigment 1')
print('this is sub assigment 1')
print('this is sub assigment 1')
print('this is sub assigment 1')
print('this is sub assigment 1')
print('this is sub assigment 1')

# %% [markdown]
# this is sub assigment 4

# %%
print('this is sub assigment 2')

# %% [markdown]
# this is sub assigment 4

# %%
print('this is sub assigment 3')

# %% [markdown]
# this is sub assigment 4

# %%
print('this is sub assigment 4')
